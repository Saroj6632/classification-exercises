# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Given the following confusion matrix, evaluate (by hand) the model's performance.
#
# |               | pred dog   | pred cat   |
# |:------------  |-----------:|-----------:|
# | actual dog    |         46 |         7  |
# | actual cat    |         13 |         34 |
#
# - cat= negative class
# - dog= positive class
#
# - ### In the context of this problem, what is a false positive?
#       Ans: Predictate a cat but turns out to be a dog
#
# - ### In the context of this problem, what is a false negative?
#         Ans: predictate cat and turns out to be a dog
#
# - ### How would you describe this model?
#         Ans:

# %% [markdown]
# ## 3.You are working as a datascientist working for Codeup Cody Creator (C3 for short), a rubber-duck manufacturing plant.
#
# ## Unfortunately, some of the rubber ducks that are produced will have defects. Your team has built several models that try to predict those defects, and the data from their predictions can be found here.
#
# ## Use the predictions dataset and pandas to help answer the following questions:
#
# - ### An internal team wants to investigate the cause of the manufacturing defects. They tell you that they want to identify as many of the ducks that have a defect as possible. Which evaluation metric would be appropriate here? Which model would be the best fit for this use case?
#
# - ### Recently several stories in the local news have come out highlighting customers who received a rubber duck with a defect, and portraying C3 in a bad light. The PR team has decided to launch a program that gives customers with a defective duck a vacation to Hawaii. They need you to predict which ducks will have defects, but tell you the really don't want to accidentally give out a vacation package when the duck really doesn't have a defect. Which evaluation metric would be appropriate here? Which model would be the best fit for this use case?

# %%
duck = pd.read_csv('model.csv')
duck
# Out:
#         actual     model1     model2     model3
# 0    No Defect  No Defect     Defect  No Defect
# 1    No Defect  No Defect     Defect     Defect
# 2    No Defect  No Defect     Defect  No Defect
# 3    No Defect     Defect     Defect     Defect
# 4    No Defect  No Defect     Defect  No Defect
# ..         ...        ...        ...        ...
# 195  No Defect  No Defect     Defect     Defect
# 196     Defect     Defect  No Defect  No Defect
# 197  No Defect  No Defect  No Defect  No Defect
# 198  No Defect  No Defect     Defect     Defect
# 199  No Defect  No Defect  No Defect     Defect
#
# [200 rows x 4 columns]

# %%
duck.actual.value_counts()
# Out:
# No Defect    184
# Defect        16
# Name: actual, dtype: int64

# %%
pd.crosstab(duck.model1,duck.actual )
# Out:
# actual     Defect  No Defect
# model1
# Defect          8          2
# No Defect       8        182

# %% [markdown]
# ### creating a baseline prediction with the most frequent one i.e no defect wrt model1

# %%
# creating a baseline prediction with the most frequent one i.e no defect wrt model1
duck['baseline_prediction']='No Defect'
duck.head()
# Out:
#       actual     model1  model2     model3 baseline_prediction
# 0  No Defect  No Defect  Defect  No Defect           No Defect
# 1  No Defect  No Defect  Defect     Defect           No Defect
# 2  No Defect  No Defect  Defect  No Defect           No Defect
# 3  No Defect     Defect  Defect     Defect           No Defect
# 4  No Defect  No Defect  Defect  No Defect           No Defect

# %%
model_1 = duck[['actual','model1','baseline_prediction']]
model_1
# Out:
#         actual     model1 baseline_prediction
# 0    No Defect  No Defect           No Defect
# 1    No Defect  No Defect           No Defect
# 2    No Defect  No Defect           No Defect
# 3    No Defect     Defect           No Defect
# 4    No Defect  No Defect           No Defect
# ..         ...        ...                 ...
# 195  No Defect  No Defect           No Defect
# 196     Defect     Defect           No Defect
# 197  No Defect  No Defect           No Defect
# 198  No Defect  No Defect           No Defect
# 199  No Defect  No Defect           No Defect
#
# [200 rows x 3 columns]

# %%
# Model and baseline accuracy

model_accuracy = (model_1.actual ==model_1.model1).mean()
baseline_accuracy = (model_1.actual == model_1.baseline_prediction).mean()
print(f'Model accuracy:{model_accuracy:.2}')
print(f'Baseline Accuracy:{baseline_accuracy:.2}')
# Out:
# Model accuracy:0.95
# Baseline Accuracy:0.92

# %%
# Recall= subset of actual positives(i.e defect)
subset = model_1[model_1.actual == 'Defect']
subset
# Out:
#      actual     model1 baseline_prediction
# 13   Defect  No Defect           No Defect
# 30   Defect     Defect           No Defect
# 65   Defect     Defect           No Defect
# 70   Defect     Defect           No Defect
# 74   Defect  No Defect           No Defect
# 87   Defect  No Defect           No Defect
# 118  Defect  No Defect           No Defect
# 135  Defect     Defect           No Defect
# 140  Defect  No Defect           No Defect
# 147  Defect     Defect           No Defect
# 163  Defect     Defect           No Defect
# 171  Defect  No Defect           No Defect
# 176  Defect  No Defect           No Defect
# 186  Defect  No Defect           No Defect
# 194  Defect     Defect           No Defect
# 196  Defect     Defect           No Defect

# %%
# calculating recall for model and baseline
model_recall = (subset.actual == subset.model1).mean()
baseline_recall = (subset.actual == subset.baseline_prediction).mean()
print(f'model recall: {model_recall:.2%}')
print(f'baseline recall: {baseline_recall:.2%}')
# Out:
# model recall: 0.5
# baseline recall: 0.0

# %%
## precision :  subsets where postive prediction is made
subset = model_1[model_1.model1=='Defect']
subset
# Out:
#         actual  model1 baseline_prediction
# 3    No Defect  Defect           No Defect
# 30      Defect  Defect           No Defect
# 62   No Defect  Defect           No Defect
# 65      Defect  Defect           No Defect
# 70      Defect  Defect           No Defect
# 135     Defect  Defect           No Defect
# 147     Defect  Defect           No Defect
# 163     Defect  Defect           No Defect
# 194     Defect  Defect           No Defect
# 196     Defect  Defect           No Defect

# %%
model_precision= (subset.actual== subset.model1).mean()
baseline_precision=(subset.actual == subset.baseline_prediction).mean()
print(f'Model precison:{model_precision:.2%}')
print(f'Baseline Precison:{baseline_precision:.2%}')
# Out:
# Model precison:80.00%
# Baseline Precison:20.00%

# %% [markdown]
# ### Using model2

# %%
model_2 = duck[['actual','model2','baseline_prediction']]
model_2
# Out:
#         actual     model2 baseline_prediction
# 0    No Defect     Defect           No Defect
# 1    No Defect     Defect           No Defect
# 2    No Defect     Defect           No Defect
# 3    No Defect     Defect           No Defect
# 4    No Defect     Defect           No Defect
# ..         ...        ...                 ...
# 195  No Defect     Defect           No Defect
# 196     Defect  No Defect           No Defect
# 197  No Defect  No Defect           No Defect
# 198  No Defect     Defect           No Defect
# 199  No Defect  No Defect           No Defect
#
# [200 rows x 3 columns]

# %%
# model and baseline accuracy
model_acuracy = (model_2.actual== model_2.model2).mean()
baseline_accuracy=(model_2.actual == model_2.baseline_prediction).mean()
print(f'Model accuracy:{model_accuracy:.2%}')
print(f'Baseline Accuracy:{baseline_accuracy:.2%}')
# Out:
# Model accuracy:95.00%
# Baseline Accuracy:92.00%

# %%
# recall:actual positives
subset=model_2[model_2.actual=='Defect']
subset
# Out:
#      actual     model2 baseline_prediction
# 13   Defect     Defect           No Defect
# 30   Defect  No Defect           No Defect
# 65   Defect     Defect           No Defect
# 70   Defect     Defect           No Defect
# 74   Defect  No Defect           No Defect
# 87   Defect     Defect           No Defect
# 118  Defect     Defect           No Defect
# 135  Defect  No Defect           No Defect
# 140  Defect     Defect           No Defect
# 147  Defect  No Defect           No Defect
# 163  Defect     Defect           No Defect
# 171  Defect     Defect           No Defect
# 176  Defect     Defect           No Defect
# 186  Defect  No Defect           No Defect
# 194  Defect  No Defect           No Defect
# 196  Defect  No Defect           No Defect

# %%
model_recall = (subset.actual == subset.model2).mean()
baseline_recall = (subset.actual == subset.baseline_prediction).mean()
print(f'model recall: {model_recall:.2%}')
print(f'baseline recall: {baseline_recall:.2%}')
# Out:
# model recall: 56.25%
# baseline recall: 0.00%

# %%
#precision: only positive predictions
subset=model_2[model_2.model2=='Defect']
subset
# Out:
#         actual  model2 baseline_prediction
# 0    No Defect  Defect           No Defect
# 1    No Defect  Defect           No Defect
# 2    No Defect  Defect           No Defect
# 3    No Defect  Defect           No Defect
# 4    No Defect  Defect           No Defect
# ..         ...     ...                 ...
# 183  No Defect  Defect           No Defect
# 185  No Defect  Defect           No Defect
# 193  No Defect  Defect           No Defect
# 195  No Defect  Defect           No Defect
# 198  No Defect  Defect           No Defect
#
# [90 rows x 3 columns]

# %%
model_precision= (subset.actual== subset.model2).mean()
baseline_precision=(subset.actual == subset.baseline_prediction).mean()
print(f'Model precison:{model_precision:.2%}')
print(f'Baseline Precison:{baseline_precision:.2%}')
# Out:
# Model precison:10.00%
# Baseline Precison:90.00%

# %% [markdown]
# ## Using model3

# %%
model_3=duck[['actual','model3','baseline_prediction']]
model_3.head()
# Out:
#       actual     model3 baseline_prediction
# 0  No Defect  No Defect           No Defect
# 1  No Defect     Defect           No Defect
# 2  No Defect  No Defect           No Defect
# 3  No Defect     Defect           No Defect
# 4  No Defect  No Defect           No Defect

# %%
# model accuracy when prediction matches the reality
model_accuracy=(model_3.actual==model_3.model3).mean()
baseline_accuracy= (model_3.actual== model_3.baseline_prediction).mean()
print(f'Model Accuracy:{model_accuracy:.2%}')
print(f'Baseline Accuracy:{baseline_accuracy:.2%}')
# Out:
# Model Accuracy:55.50%
# Baseline Accuracy:92.00%

# %%
# recall: when actual is defect
subset= model_3[model_3.actual=='Defect']
subset
# Out:
#      actual     model3 baseline_prediction
# 13   Defect     Defect           No Defect
# 30   Defect     Defect           No Defect
# 65   Defect     Defect           No Defect
# 70   Defect     Defect           No Defect
# 74   Defect     Defect           No Defect
# 87   Defect     Defect           No Defect
# 118  Defect  No Defect           No Defect
# 135  Defect     Defect           No Defect
# 140  Defect     Defect           No Defect
# 147  Defect     Defect           No Defect
# 163  Defect     Defect           No Defect
# 171  Defect     Defect           No Defect
# 176  Defect     Defect           No Defect
# 186  Defect  No Defect           No Defect
# 194  Defect     Defect           No Defect
# 196  Defect  No Defect           No Defect

# %%
model_recall = (subset.actual== subset.model3).mean()
print(f'Model recall:{model_recall:.2%}')
baseline_recall = (subset.actual== subset.baseline_prediction).mean()
print(f'Baseline reacall:{baseline_recall:.2%}')
# Out:
# Model recall:13.13%
# Baseline reacall:86.87%

# %%
#precision: when model3==defect
subset= model_3[model_3.model3=='Defect']
subset
# Out:
#         actual  model3 baseline_prediction
# 1    No Defect  Defect           No Defect
# 3    No Defect  Defect           No Defect
# 5    No Defect  Defect           No Defect
# 9    No Defect  Defect           No Defect
# 13      Defect  Defect           No Defect
# ..         ...     ...                 ...
# 193  No Defect  Defect           No Defect
# 194     Defect  Defect           No Defect
# 195  No Defect  Defect           No Defect
# 198  No Defect  Defect           No Defect
# 199  No Defect  Defect           No Defect
#
# [99 rows x 3 columns]

# %%
model_precision= (subset.actual== subset.model3).mean()
baseline_precision=(subset.actual == subset.baseline_prediction).mean()
print(f'Model precison:{model_precision:.2%}')
print(f'Baseline Precison:{baseline_precision:.2%}')
# Out:
# Model precison:13.13%
# Baseline Precison:86.87%

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## 4.You are working as a data scientist for Gives You Paws ™, a subscription based service that shows you cute pictures of dogs or cats (or both for an additional fee).
#
# ## At Gives You Paws, anyone can upload pictures of their cats or dogs. The photos are then put through a two step process. First an automated algorithm tags pictures as either a cat or a dog (Phase I). Next, the photos that have been initially identified are put through another round of review, possibly with some human oversight, before being presented to the users (Phase II).
#
# ## Several models have already been developed with the data, and you can find their results here.
#
# ## Given this dataset, use pandas to create a baseline model (i.e. a model that just predicts the most common class) and answer the following questions:
#
# - ### **A** . In terms of accuracy, how do the various models compare to the baseline model? Are any of the models     better than the baseline?
# - ### **B** . Suppose you are working on a team that solely deals with dog pictures. Which of these models would you recomend for Phase I? For Phase II?
# - ### **C** . Suppose you are working on a team that solely deals with cat pictures. Which of these models would you recomend for Phase I? For Phase II?

# %%
df= pd.read_csv('gives_you_paws.csv')
df
# Out:
#      actual model1 model2 model3 model4
# 0       cat    cat    dog    cat    dog
# 1       dog    dog    cat    cat    dog
# 2       dog    cat    cat    cat    dog
# 3       dog    dog    dog    cat    dog
# 4       cat    cat    cat    dog    dog
# ...     ...    ...    ...    ...    ...
# 4995    dog    dog    dog    dog    dog
# 4996    dog    dog    cat    cat    dog
# 4997    dog    cat    cat    dog    dog
# 4998    cat    cat    cat    cat    dog
# 4999    dog    dog    dog    dog    dog
#
# [5000 rows x 5 columns]

# %%
df.actual.value_counts()
# Out:
# dog    3254
# cat    1746
# Name: actual, dtype: int64

# %%
# since DOG is the most common, dog is set as baseline
df['base_pred']='dog'
df.head()
# Out:
#   actual model1 model2 model3 model4 base_pred
# 0    cat    cat    dog    cat    dog       dog
# 1    dog    dog    cat    cat    dog       dog
# 2    dog    cat    cat    cat    dog       dog
# 3    dog    dog    dog    cat    dog       dog
# 4    cat    cat    cat    dog    dog       dog

# %%
columns= df.columns

# %%
# model and baseline accuracy i.e actual == prediction
for col in columns:
    model_accuracy=(df.actual == df[col]).mean()
    baseline_accuracy= (df.actual == df.base_pred).mean()
print(f'model accuracy for{col} {model_accuracy:.2%}')
print(f'baseline accuracyfor{col} {baseline_accuracy:.2%}')
print('..............')
print('\n')
# Out:
# model accuracy forbase_pred 65.08%
# baseline accuracyforbase_pred 65.08%
# ..............

# %%
model_accuracy=(df.actual == df.model1).mean()
baseline_accuracy= (df.actual == df.base_pred).mean()
print(f'model accuracy for model1: {model_accuracy:.2%}')
print(f'baseline accuracy for model1: {baseline_accuracy:.2%}')

model_accuracy=(df.actual == df.model2).mean()
baseline_accuracy= (df.actual == df.base_pred).mean()
print(f'model accuracy for model2: {model_accuracy:.2%}')
print(f'baseline accuracy for model2: {baseline_accuracy:.2%}')

model_accuracy=(df.actual == df.model3).mean()
baseline_accuracy= (df.actual == df.base_pred).mean()
print(f'model accuracy for model3: {model_accuracy:.2%}')
print(f'baseline accuracy for model3: {baseline_accuracy:.2%}')

model_accuracy=(df.actual == df.model4).mean()
baseline_accuracy= (df.actual == df.base_pred).mean()
print(f'model accuracy for model4: {model_accuracy:.2%}')
print(f'baseline accuracy for model4: {baseline_accuracy:.2%}')
# Out:
# model accuracy for model1: 80.74%
# baseline accuracy for model1: 65.08%
# model accuracy for model2: 63.04%
# baseline accuracy for model2: 65.08%
# model accuracy for model3: 50.96%
# baseline accuracy for model3: 65.08%
# model accuracy for model4: 74.26%
# baseline accuracy for model4: 65.08%

# %%
# recall: when actual is dog
subset= df[df.actual=='dog']
subset
# Out:
#      actual model1 model2 model3 model4 base_pred
# 1       dog    dog    cat    cat    dog       dog
# 2       dog    cat    cat    cat    dog       dog
# 3       dog    dog    dog    cat    dog       dog
# 5       dog    dog    dog    dog    dog       dog
# 8       dog    dog    cat    dog    dog       dog
# ...     ...    ...    ...    ...    ...       ...
# 4993    dog    dog    cat    dog    dog       dog
# 4995    dog    dog    dog    dog    dog       dog
# 4996    dog    dog    cat    cat    dog       dog
# 4997    dog    cat    cat    dog    dog       dog
# 4999    dog    dog    dog    dog    dog       dog
#
# [3254 rows x 6 columns]

# %%
model_recall = (subset.actual== subset.model1).mean()
print(f'Model recall for model1:{model_recall:.2%}')
baseline_recall = (subset.actual== subset.base_pred).mean()
print(f'Baseline recall for model1:{baseline_recall:.2%}')

model_recall = (subset.actual== subset.model2).mean()
print(f'Model recall for model2:{model_recall:.2%}')
baseline_recall = (subset.actual== subset.base_pred).mean()
print(f'Baseline recall for model2:{baseline_recall:.2%}')

model_recall = (subset.actual== subset.model3).mean()
print(f'Model recall for model3:{model_recall:.2%}')
baseline_recall = (subset.actual== subset.base_pred).mean()
print(f'Baseline recall for model3:{baseline_recall:.2%}')

model_recall = (subset.actual== subset.model4).mean()
print(f'Model recall for model4:{model_recall:.2%}')
baseline_recall = (subset.actual== subset.base_pred).mean()
print(f'Baseline recall for model4:{baseline_recall:.2%}')
# Out:
# Model recall for model1:80.33%
# Baseline recall for model1:100.00%
# Model recall for model2:49.08%
# Baseline recall for model2:100.00%
# Model recall for model3:50.86%
# Baseline recall for model3:100.00%
# Model recall for model4:95.57%
# Baseline recall for model4:100.00%

# %%
#precision: when model==dog
subset= df[df.=='dog']
subset

# %%
model_precision= (subset.actual== subset.model3).mean()
baseline_precision=(subset.actual == subset.baseline_prediction).mean()
print(f'Model precison:{model_precision:.2%}')
print(f'Baseline Precison:{baseline_precision:.2%}')

# %% [markdown]
# # 5.Follow the links below to read the documentation about each function, then apply those functions to the data from the previous problem.
#
# - sklearn.metrics.accuracy_score
# - sklearn.metrics.precision_score
# - sklearn.metrics.recall_score
# - sklearn.metrics.classification_report
